# %%
Task 7

My sql:
    
    1. create a table for attribute dataset and dress dataset
    2. do a bulk load for these two table for respective dataset
    3. read these dataset in pandas as a dataframe
    4. convert attribute data set in json format
    5. store these dataset(attribute dataset) into mongodb (json dataset)
    6. in sql task try to perform left outer join operation with attribute and dress sales dataset on column Dress_ID
    7. write a sql query to find out how many unique dress that we have based on dress ID.
    8. try to find out how many dress is having recommendation 0; sql 
    9. try to find out total dress sale for individual Dress_ID. ; sql 
    10. try to find out third highest most selling dress_id # total sales

# %%
# 1. create a table for attribute dataset and dress dataset
# 2. do a bulk load for these two table for respective dataset

show databases;
create database task8;
use task8;

create table if not exists attribute(Dress_ID int(15),
Style varchar(20),
Price varchar(15),
Rating float(5,2),
Size varchar(10),
Season varchar(20),
NeckLine varchar(20),
SleeveLength varchar(20),
waiseline varchar(20),
Material varchar(20),
FabricType varchar(20),
Decoration varchar(20),
PatternType varchar(20),
Recommendation int(2));

show tables;
select * from attribute;

set global local_infile = True;
show global variables like 'local_infile';

load data local infile "D:\\attribute.csv"
into table attribute
fields terminated by ','
enclosed by '"'
lines terminated by '\n'
ignore 1 rows;

select * from attribute;

# table attribute has been created

show databases;
use task8;
create table if not exists dresssales(Dress_ID int(15),
`29-08-2013` varchar(20),
`31-08-2013` varchar(20),
`09-02-2013` varchar(20),
`09-04-2013` varchar(20),
`09-06-2013` varchar(20),
`09-08-2013` varchar(20),
`09-10-2013` varchar(20),
`09-12-2013`varchar(20),
`14-09-2013` varchar(20),
`16-09-2013` varchar(20),
`18-09-2013` varchar(20),
`20-09-2013` varchar(20),
`22-09-2013` varchar(20),
`24-09-2013` varchar(20),
`26-09-2013` varchar(20),
`28-09-2013` varchar(20),
`30-09-2013` varchar(20),
`10-02-2013` varchar(20),
`10-04-2013` varchar(20),
`10-06-2013` varchar(20),
`10-08-2010` varchar(20),
`10-10-2013` varchar(20),
`10-12-2013` varchar(20));

set global local_infile = True;
show global variables like 'local_infile';

load data local infile "D:\\dresssales.csv"
into table dresssales
fields terminated by ','
enclosed by '"'
lines terminated by '\n'
ignore 1 rows;

select * from dresssales;

# table dresssales has been created.
# Out:
# 1007 (HY000): Can't create database 'task8'; database exists

# %%
# 3. read these dataset in pandas as a dataframe

import pandas as pd
attributepd = pd.read_excel(r'C:\Users\Abhishek Dave\Downloads\data fsds -20220724T095101Z-001\data fsds\Attribute DataSet.xlsx')
dresspd = pd.read_excel(r'C:\Users\Abhishek Dave\Downloads\data fsds -20220724T095101Z-001\data fsds\Dress Sales.xlsx')

# %%
attributepd
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
dresspd
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
# 4. convert attribute data set in json format

attributepd.to_json('D://attribute_json.json')

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "pymongo[srv]"
# Out:
# ...
#   Using cached dnspython-2.2.1-py3-none-any.whl (269 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#data = pd.read_csv(r"D:\attribute.csv")
#data
data1 = data.to_dict(orient='record')
data1
# Out:
# C:\Users\Abhishek Dave\AppData\Local\Temp\ipykernel_6140\3764311020.py:3: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data1 = data.to_dict(orient='record')
# [{'Dress_ID': 1006032852,
#   'Style': 'Sexy',
#   'Price': 'Low',
#   'Rating': 4.6,
#   'Size': 'M',
#   'Season': 'Summer',
#   'NeckLine': 'o-neck',
#   'SleeveLength': 'sleevless',
#   'waiseline': 'empire',
#   'Material': nan,
#   'FabricType': 'chiffon',
#   'Decoration': 'ruffles',
#   'Pattern Type': 'animal',
#   'Recommendation': 1},
#  {'Dress_ID': 1212192089,
#   'Style': 'Casual',
#   'Price': 'Low',
#   'Rating': 0.0,
#   'Size': 'L',
#   'Season': 'Summer',
#   'NeckLine': 'o-neck',
#   'SleeveLength': 'Petal',
#   'waiseline': 'natural',
#   'Material': 'microfiber',
#   'FabricType': nan,
#   'Decoration': 'ruffles',
# ...

# %%
# 5. store these dataset(attribute dataset) into mongodb (json dataset)
import pymongo
try:
    
    client = pymongo.MongoClient("mongodb+srv://mongodb:mongodb@cluster0.cqmbjyo.mongodb.net/?retryWrites=true&w=majority")
    db = client.test
    print("Connection established")
    
    database = client['task8']
    collection = database['question5']
    #collection.insert_one({'abhi': [1,2,3,4,5], 'dave': 2528})
    collection.insert_many(data1)
    

except Exception as e:
    print(e)
# Out:
# Connection established

# %%
# 6. in sql task try to perform left outer join operation with attribute and dress sales dataset on column Dress_ID
select * from attribute left join dresssales on attribute.Dress_ID = dresssales.Dress_ID;

# %%
# 7. write a sql query to find out how many unique dress that we have based on dress ID.
select count(Dress_ID) from attribute;

# %%
# 8. try to find out how many dress is having recommendation 0; sql 
select Dress_ID, Recommendation from attribute where Recommendation = 0; # It will give all Dress_ID and 0 Recommendation dresses
select count(Dress_ID) from attribute where Recommendation = 0; # it will return us the number of dress haveing recommendaton 0

# %%
# 9. try to find out total dress sale for individual Dress_ID. ; sql

# %%
# 10. try to find out third highest most selling dress_id # total sales
